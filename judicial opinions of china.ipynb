# %%
# -*- coding: utf-8 -*-
import requests,urllib2,re,time,random
from bs4 import BeautifulSoup

s = random.randint(5,10)
headers={'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
'Accept-Encoding':'gzip, deflate, sdch',
'Connection':'keep-alive',
'Cookie':'JSESSIONID=04119D7BD29A9D2D5ED06DAFE5D35320; __jsluid=70773b9878dd699fcf905fd9bc1c0b2e; Hm_lvt_692544717e4ca5489bff77b2e9b28e7b=1439119886,1439135938; Hm_lpvt_692544717e4ca5489bff77b2e9b28e7b=1441631996',
'Host':'www.court.gov.cn',
'Referer':'http://www.court.gov.cn/extension/simpleSearch.htm?keyword=%E5%8F%B0%E5%95%86&caseCode=&beginDate=2014-01-02&endDate=2015-09-07&adv=1&orderby=&order=',
'Upgrade-Insecure-Requests':'1',
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36'
}

def downloadfile(pg_url):
    res = requests.get(pg_url,headers=headers)
    res.encoding='utf8'
    htmlpage = res.text
    soup = BeautifulSoup(htmlpage)
    #print soup
    ele =soup.select('div')
    #print ele
    #title = ele[17].text.strip().encode('utf8')
    title = soup.select('#wsTitle')[0].text.encode('utf8')
    time = soup.select('#wsTime')[0].text.encode('utf8').split("：")[1].replace("-","")[0:8]
    #print title
    #print time
    f = open('data/%s%s.txt'%(time.decode('utf8'),title.decode('utf8')),'w')
    headname = title +'\n'+time+'\n'
    f.write(headname)
    for i in range(15,80):
        if len(ele[i].text):
            contents = ele[i].text.strip().encode('utf8')+'\n'
            f.write(contents)
        else :
            break        
    f.close()

#http://www.court.gov.cn/zgcpwsw/mshz/
#共7203条记录  共721页
page=730 #24119
for pp in range(276,page+1):
    link='http://www.court.gov.cn/extension/simpleSearch.htm?keyword=%E5%8F%B0%E5%95%86&caseCode=&beginDate=2000-01-01&endDate=2015-09-07&adv=1&orderby=&order=&page={}'.format(pp)
    res = requests.get(link, headers=headers)
    res_text= res.text.encode('utf-8')
    soup_m = BeautifulSoup(res_text)
    #print soup_m.select('.tdbgs_odd')
    for ele in soup_m.select('.tdbgs_odd'):
        pg_url = ele.select('a')[0]['href']
        #print pg_url
        downloadfile(pg_url)
    for ele in soup_m.select('.tdbgs_even'):
        pg_url= ele.select('a')[0]['href']
        #print pg_url
        downloadfile(pg_url)
    print pp
    time.sleep(s)
# Out:
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 441
# ...

# %%
# -*- coding: utf-8 -*-
import urllib2,re
from bs4 import BeautifulSoup
pg_link ='http://www.court.gov.cn/zgcpwsw/sd/sdsqdszjrmfy/qdssnqrmfy/ms/201508/t20150812_10153773.htm'
page = urllib2.urlopen(pg_link)
soup = BeautifulSoup(page,fromEncoding="utf8")
soup.originalEncoding
soup.prettify()
ele =soup.select('div')
#title = ele[17].text.strip().encode('utf8')
title = soup.select('#wsTitle')[0].text.encode('utf8')
time = soup.select('#wsTime')[0].text.encode('utf8').split("：")[1].replace("-","")[0:8]
#time2 = time
f = open('data/%s%s.txt'%(time,title),'w')
headname = title +'\n'+time+'\n'
f.write(headname)
for i in range(15,80):
    if len(ele[i].text):
        contents = ele[i].text.strip().encode('utf8')+'\n'
        f.write(contents)
    else :
        break        
f.close()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-2db8f4b6f815> in <module>()
#       3 from bs4 import BeautifulSoup
#       4 pg_link ='http://www.court.gov.cn/zgcpwsw/sd/sdsqdszjrmfy/qdssnqrmfy/ms/201508/t20150812_10153773.htm'
# ----> 5 page = urllib2.urlopen(pg_link)
#       6 soup = BeautifulSoup(page,fromEncoding="utf8")
#       7 soup.originalEncoding
#
# C:\Python27\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Python27\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     435         for processor in self.process_response.get(protocol, []):
#     436             meth = getattr(processor, meth_name)
# --> 437             response = meth(req, response)
# ...

# %%
import re
s1=" i am 30 !"
w1 = "中国共产党新闻"
w2 = "中国共产党新闻 我们 "
if re.search(w2, w1)!= 'none':
    print('match')
else:
    print('not match')
# Out:
# match

# %%
a = "Free your mind."
b = "Welcome to the desert... of the real."
c = "What is real? How do you define real?"
d = "There is no spoon."
 

print(c)
print(c.split(" ")[2])
print()
# Out:
# What is real? How do you define real?
# real?
# ()

# %%
a = '提交时间：2015-08-12    1'
b = a.split('：')[1].replace('-','')[0:8]
print b
# Out:
# 20150812
